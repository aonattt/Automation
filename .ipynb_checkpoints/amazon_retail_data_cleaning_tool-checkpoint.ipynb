# %% [markdown]
# # Amazon Data Cleaning Automation Tool
#
# ## Overview
# This notebook automates the process of cleaning and transforming data for Amazon product listings. The objective is to ensure the data meets required quality standards before analysis and reporting.
#
# Key tasks include:
# - Removing duplicates
# - Handling missing values
# - Normalizing product names
# - Ensuring consistent date formats

# %% [markdown]
# ## 1. Import Libraries and Load Data

# %%
# Importing necessary libraries
import pandas as pd
from ast import literal_eval
from itertools import repeat
from datetime import datetime
import os
from openpyxl import Workbook
from openpyxl import load_workbook
from openpyxl.styles import PatternFill, Border, Side, Alignment, Protection, Font, Fill
from openpyxl.styles import numbers

# %%
downloads_folder = os.path.join(os.path.expanduser("~"), "Downloads")
csv_filename = "www.amazon.com_20241013_193934.csv"
csv_file_path = os.path.join(downloads_folder, csv_filename)
# Read the CSV file into a DataFrame
df = pd.read_csv(csv_file_path)

# %%
# Get current date in YYYYMMDD format
current_date = datetime.now().strftime('%Y%m%d')

# %% [markdown]
# # Section: Data Cleaning and Preprocessing

# %%
# Renaming columns
df = df.rename(columns={'Listing_price': 'regular_retail_price', 'promo_price': 'discounted_retail_price'})

# Handling missing values
df['ASIN'].fillna('None', inplace=True)
df['sellers'].fillna('[]', inplace=True)

# Dropping unnecessary columns
columns_to_drop = ['images', 'warning', 'error', 'error_code', 'job_id', 'collector_id']
df = df.drop(columns=columns_to_drop, axis=1)

# Cleaning specific columns
for i in range(len(df)):
    try:
        df.loc[i, 'bullet_points'] = df.loc[i, 'bullet_points'].replace(']', "").replace('[', "")
        df.loc[i, 'product_information'] = df.loc[i, 'product_information'].replace('{', "").replace('}', "")
        df.loc[i, 'combination'] = df.loc[i, 'combination'].replace('{', "").replace('}', "").replace(']', "").replace('[', "").replace("name", "Option")
        df.loc[i, 'sellers'] = df.loc[i, 'sellers'].replace('UnbeatableSale, Inc', "UnbeatableSale")
    except:
        continue

# Filling NaN values in specific columns
df['product_information'].fillna('None', inplace=True)
df['bullet_points'].fillna('None', inplace=True)
df['combination'].fillna('None', inplace=True)

# %% [markdown]
# # Section: Processing Product Information Column

# %%
# Extracting and cleaning 'product_information' column
product_information = df[['ASIN', 'product_information']]
product_information['product_information'].fillna('{}', inplace=True)

# Standardizing certain key terms in the product information
product_information['product_information'] = product_information['product_information'].replace("Assembly required", "Assembly Required", regex=True)
product_information['product_information'] = product_information['product_information'].replace("Number of pieces", "Number of Pieces", regex=True)
product_information['product_information'] = product_information['product_information'].replace("Seat height", "Seat Height", regex=True)

# Initialize a list to hold the processed dataframes
dataframes = []

# Iterate over rows to convert product information into individual dataframes
for index, row in product_information.iterrows():
    try:
        # Clean any non-dictionary-like formats (if necessary)
        product_info = row['product_information']
        
        # Enclose the string in curly braces if they are missing
        if not (product_info.startswith('{') and product_info.endswith('}')):
            product_info = '{' + product_info.strip() + '}'
        
        # Safely evaluate the string representation of a dictionary
        data_dict = literal_eval(product_info)
        
        # If data_dict is a dictionary, proceed to create a DataFrame
        if isinstance(data_dict, dict):
            dF = pd.DataFrame(data_dict, index=[row['ASIN']])
            dataframes.append(dF)
        else:
            print(f"Non-dict data at index {index}")
    
    except (ValueError, SyntaxError) as e:
        print(f"Error converting to dictionary at index {index}: {e}")
        # Handle the error (optional: append NaN or empty DataFrame)

# Concatenate all the DataFrames into one combined DataFrame
if dataframes:
    pi_combined = pd.concat(dataframes)
else:
    print("No valid product information found.")
# Out:
# C:\Users\Aykut\AppData\Local\Temp\ipykernel_3884\3361797429.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   product_information['product_information'].fillna('{}', inplace=True)
# C:\Users\Aykut\AppData\Local\Temp\ipykernel_3884\3361797429.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   product_information['product_information'] = product_information['product_information'].replace("Assembly required", "Assembly Required", regex=True)
# C:\Users\Aykut\AppData\Local\Temp\ipykernel_3884\3361797429.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   product_information['product_information'] = product_information['product_information'].replace("Number of pieces", "Number of Pieces", regex=True)
# C:\Users\Aykut\AppData\Local\Temp\ipykernel_3884\3361797429.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   product_information['product_information'] = product_information['product_information'].replace("Seat height", "Seat Height", regex=True)
# Non-dict data at index 6071
# Non-dict data at index 6072
# Non-dict data at index 6073
# Non-dict data at index 6074
# Non-dict data at index 6075
# Non-dict data at index 6076
# Non-dict data at index 6077
# Non-dict data at index 6078
# Non-dict data at index 6079
# Non-dict data at index 6080
# Non-dict data at index 6081
# Non-dict data at index 6082
# Non-dict data at index 6083
# Non-dict data at index 6084
# Non-dict data at index 6085
# Non-dict data at index 6086
# Non-dict data at index 6087
# Non-dict data at index 6088
# Non-dict data at index 6089
# Non-dict data at index 6090
# Non-dict data at index 6091
# Non-dict data at index 6092
# Non-dict data at index 6093
# Non-dict data at index 6094
# Non-dict data at index 6095
# Non-dict data at index 6096
# Non-dict data at index 6097
# Non-dict data at index 6098
# Non-dict data at index 6099
# Non-dict data at index 6100
# Non-dict data at index 6101
# Non-dict data at index 6102
# Non-dict data at index 6103
# Non-dict data at index 6104
# Non-dict data at index 6105
# Non-dict data at index 6106
# Non-dict data at index 6107
# Non-dict data at index 6108
# Non-dict data at index 6109
# Non-dict data at index 6110
# Non-dict data at index 6111
# Non-dict data at index 6112
# Non-dict data at index 6113
# Non-dict data at index 6114
# Non-dict data at index 6115
# Non-dict data at index 6116
# Non-dict data at index 6117
# Non-dict data at index 6118
# Non-dict data at index 6119
# Non-dict data at index 6120
# Non-dict data at index 6121
# Non-dict data at index 6122
# Non-dict data at index 6123
# Non-dict data at index 6124
# Non-dict data at index 6125
# Non-dict data at index 6126
# Non-dict data at index 6127
# Non-dict data at index 6128
# Non-dict data at index 6129
# Non-dict data at index 6130
# Non-dict data at index 6131
# Non-dict data at index 6132
# Non-dict data at index 6133
# Non-dict data at index 6134
# Non-dict data at index 6135
# Non-dict data at index 6136
# Non-dict data at index 6137
# Non-dict data at index 6138
# Non-dict data at index 6139
# Non-dict data at index 6140
# Non-dict data at index 6141
# Non-dict data at index 6142
# Non-dict data at index 6143
# Non-dict data at index 6144
# Non-dict data at index 6145
# Non-dict data at index 6146
# Non-dict data at index 6147
# Non-dict data at index 6148
# Non-dict data at index 6149
# Non-dict data at index 6150
# Non-dict data at index 6151
# Non-dict data at index 6152
# Non-dict data at index 6153
# Non-dict data at index 6154
# Non-dict data at index 6155
# Non-dict data at index 6156
# Non-dict data at index 6157
# Non-dict data at index 6158
# Non-dict data at index 6159
# Non-dict data at index 6160
# Non-dict data at index 6161
# Non-dict data at index 6162
# Non-dict data at index 6163
# Non-dict data at index 6164
# Non-dict data at index 6165
# Non-dict data at index 6166
# Non-dict data at index 6167
# Non-dict data at index 6168
# Non-dict data at index 6169
# Non-dict data at index 6170
# Non-dict data at index 6171
# Non-dict data at index 6172
# Non-dict data at index 6173
# Non-dict data at index 6174
# Non-dict data at index 6175
# Non-dict data at index 6176
# Non-dict data at index 6177
# Non-dict data at index 6178
# Non-dict data at index 6179
# Non-dict data at index 6180
# Non-dict data at index 6181
# Non-dict data at index 6182
# Non-dict data at index 6183
# Non-dict data at index 6184
# Non-dict data at index 6185
# Non-dict data at index 6186
# Non-dict data at index 6187
# Non-dict data at index 6188
# Non-dict data at index 6189
# Non-dict data at index 6190
# Non-dict data at index 6191
# Non-dict data at index 6192
# Non-dict data at index 6193
# Non-dict data at index 6194
# Non-dict data at index 6195
# Non-dict data at index 6196
# Non-dict data at index 6197
# Non-dict data at index 6198
# Non-dict data at index 6199
# Non-dict data at index 6200
# Non-dict data at index 6201
# Non-dict data at index 6202
# Non-dict data at index 6203
# Non-dict data at index 6204
# Non-dict data at index 6205
# Non-dict data at index 6206
# Non-dict data at index 6207
# Non-dict data at index 6208
# Non-dict data at index 6209
# Non-dict data at index 6210
# Non-dict data at index 6211
# Non-dict data at index 6212
# Non-dict data at index 6213
# Non-dict data at index 6214
# Non-dict data at index 6215
# Non-dict data at index 6216
# Non-dict data at index 6217
# Non-dict data at index 6218
# Non-dict data at index 6219
# Non-dict data at index 6220
# Non-dict data at index 6221
# Non-dict data at index 6222
# Non-dict data at index 6223
# Non-dict data at index 6224
# Non-dict data at index 6225
# Non-dict data at index 6226
# Non-dict data at index 6227
# Non-dict data at index 6228
# Non-dict data at index 6229
# Non-dict data at index 6230
# Non-dict data at index 6231
# Non-dict data at index 6232
# Non-dict data at index 6233
# Non-dict data at index 6234
# Non-dict data at index 6235
# Non-dict data at index 6236
# Non-dict data at index 6237
# Non-dict data at index 6238
# Non-dict data at index 6239
# Non-dict data at index 6240
# Non-dict data at index 6241
# Non-dict data at index 6242
# Non-dict data at index 6243
# Non-dict data at index 6244
# Non-dict data at index 6245
# Non-dict data at index 6246
# Non-dict data at index 6247
# Non-dict data at index 6248
# Non-dict data at index 6249
# Non-dict data at index 6250
# Non-dict data at index 6251
# Non-dict data at index 6252
# Non-dict data at index 6253
# Non-dict data at index 6254
# Non-dict data at index 6255
# Non-dict data at index 6256
# Non-dict data at index 6257
# Non-dict data at index 6258
# Non-dict data at index 6259
# Non-dict data at index 6260
# Non-dict data at index 6261
# Non-dict data at index 6262
# Non-dict data at index 6263
# Non-dict data at index 6264
# Non-dict data at index 6265
# Non-dict data at index 6266
# Non-dict data at index 6267
# Non-dict data at index 6268
# Non-dict data at index 6269
# Non-dict data at index 6270
# Non-dict data at index 6271
# Non-dict data at index 6272
# Non-dict data at index 6273
# Non-dict data at index 6274
# Non-dict data at index 6275
# Non-dict data at index 6276
# Non-dict data at index 6277
# Non-dict data at index 6278
# Non-dict data at index 6279
# Non-dict data at index 6280
# Non-dict data at index 6281
# Non-dict data at index 6282
# Non-dict data at index 6283
# Non-dict data at index 6284
# Non-dict data at index 6285
# Non-dict data at index 6286
# Non-dict data at index 6287
# Non-dict data at index 6288
# Non-dict data at index 6289
# Non-dict data at index 6290
# Non-dict data at index 6291
# Non-dict data at index 6292
# Non-dict data at index 6293
# Non-dict data at index 6294
# Non-dict data at index 6295
# Non-dict data at index 6296
# Non-dict data at index 6297
# Non-dict data at index 6298
# Non-dict data at index 6299
# Non-dict data at index 6300
# Non-dict data at index 6301
# Non-dict data at index 6302
# Non-dict data at index 6303
# Non-dict data at index 6304
# Non-dict data at index 6305
# Non-dict data at index 6306
# Non-dict data at index 6307
# Non-dict data at index 6308
# Non-dict data at index 6309
# Non-dict data at index 6310
# Non-dict data at index 6311
# Non-dict data at index 6312
# Non-dict data at index 6313
# Non-dict data at index 6314
# Non-dict data at index 6315
# Non-dict data at index 6316
# Non-dict data at index 6317
# Non-dict data at index 6318
# Non-dict data at index 6319
# Non-dict data at index 6320
# Non-dict data at index 6321
# Non-dict data at index 6322
# Non-dict data at index 6323
# Non-dict data at index 6324
# Non-dict data at index 6325
# Non-dict data at index 6326
# Non-dict data at index 6327
# Non-dict data at index 6328
# Non-dict data at index 6329
# Non-dict data at index 6330
# Non-dict data at index 6331
# Non-dict data at index 6332
# Non-dict data at index 6333
# Non-dict data at index 6334
# Non-dict data at index 6335
# Non-dict data at index 6336
# Non-dict data at index 6337
# Non-dict data at index 6338
# Non-dict data at index 6339
# Non-dict data at index 6340
# Non-dict data at index 6341
# Non-dict data at index 6342
# Non-dict data at index 6343
# Non-dict data at index 6344
# Non-dict data at index 6345
# Non-dict data at index 6346
# Non-dict data at index 6347
# Non-dict data at index 6348
# Non-dict data at index 6349
# Non-dict data at index 6350
# Non-dict data at index 6351
# Non-dict data at index 6352
# Non-dict data at index 6353
# Non-dict data at index 6354
# Non-dict data at index 6355
# Non-dict data at index 6356
# Non-dict data at index 6357
# Non-dict data at index 6358
# Non-dict data at index 6359
# Non-dict data at index 6360
# Non-dict data at index 6361
# Non-dict data at index 6362
# Non-dict data at index 6363
# Non-dict data at index 6364
# Non-dict data at index 6365
# Non-dict data at index 6366
# Non-dict data at index 6367
# Non-dict data at index 6368
# Non-dict data at index 6369
# Non-dict data at index 6370
# Non-dict data at index 6371
# Non-dict data at index 6372
# Non-dict data at index 6373
# Non-dict data at index 6374
# Non-dict data at index 6375
# Non-dict data at index 6376
# Non-dict data at index 6377
# Non-dict data at index 6378
# Non-dict data at index 6379
# Non-dict data at index 6380
# Non-dict data at index 6381
# Non-dict data at index 6382
# Non-dict data at index 6383
# Non-dict data at index 6384
# Non-dict data at index 6385
# Non-dict data at index 6386
# Non-dict data at index 6387
# Non-dict data at index 6388
# Non-dict data at index 6389
# Non-dict data at index 6390
# Non-dict data at index 6391
# Non-dict data at index 6392
# Non-dict data at index 6393
# Non-dict data at index 6394
# Non-dict data at index 6395
# Non-dict data at index 6396
# Non-dict data at index 6397
# Non-dict data at index 6398
# Non-dict data at index 6399
# Non-dict data at index 6400
# Non-dict data at index 6401
# Non-dict data at index 6402
# Non-dict data at index 6403
# Non-dict data at index 6404
# Non-dict data at index 6405
# Non-dict data at index 6406
# Non-dict data at index 6407
# Non-dict data at index 6408
# Non-dict data at index 6409
# Non-dict data at index 6410
# Non-dict data at index 6411
# Non-dict data at index 6412
# Non-dict data at index 6413
# Non-dict data at index 6414
# Non-dict data at index 6415
# Non-dict data at index 6416
# Non-dict data at index 6417
# Non-dict data at index 6418
# Non-dict data at index 6419
# Non-dict data at index 6420
# Non-dict data at index 6421
# Non-dict data at index 6422
# Non-dict data at index 6423
# Non-dict data at index 6424
# Non-dict data at index 6425
# Non-dict data at index 6426
# Non-dict data at index 6427
# Non-dict data at index 6428
# Non-dict data at index 6429
# Non-dict data at index 6430
# Non-dict data at index 6431
# Non-dict data at index 6432
# Non-dict data at index 6433
# Non-dict data at index 6434
# Non-dict data at index 6435
# Non-dict data at index 6436
# Non-dict data at index 6437
# Non-dict data at index 6438
# Non-dict data at index 6439
# Non-dict data at index 6440
# Non-dict data at index 6441
# Non-dict data at index 6442
# Non-dict data at index 6443
# Non-dict data at index 6444
# Non-dict data at index 6445
# Non-dict data at index 6446
# Non-dict data at index 6447
# Non-dict data at index 6448
# Non-dict data at index 6449
# Non-dict data at index 6450
# Non-dict data at index 6451
# Non-dict data at index 6452
# Non-dict data at index 6453
# Non-dict data at index 6454
# Non-dict data at index 6455
# Non-dict data at index 6456
# Non-dict data at index 6457
# Non-dict data at index 6458
# Non-dict data at index 6459
# Non-dict data at index 6460
# Non-dict data at index 6461
# Non-dict data at index 6462
# Non-dict data at index 6463
# Non-dict data at index 6464
# Non-dict data at index 6465
# Non-dict data at index 6466
# Non-dict data at index 6467
# Non-dict data at index 6468
# Non-dict data at index 6469
# Non-dict data at index 6470
# Non-dict data at index 6471
# Non-dict data at index 6472
# Non-dict data at index 6473
# Non-dict data at index 6474
# Non-dict data at index 6475
# Non-dict data at index 6476
# Non-dict data at index 6477
# Non-dict data at index 6478
# Non-dict data at index 6479
# Non-dict data at index 6480
# Non-dict data at index 6481
# Non-dict data at index 6482
# Non-dict data at index 6483
# Non-dict data at index 6484
# Non-dict data at index 6485
# Non-dict data at index 6486
# Non-dict data at index 6487
# Non-dict data at index 6488
# Non-dict data at index 6489
# Non-dict data at index 6490
# Non-dict data at index 6491
# Non-dict data at index 6492
# Non-dict data at index 6493
# Non-dict data at index 6494
# Non-dict data at index 6495
# Non-dict data at index 6496
# Non-dict data at index 6497
# Non-dict data at index 6498
# Non-dict data at index 6499
# Non-dict data at index 6500
# Non-dict data at index 6501
# Non-dict data at index 6502
# Non-dict data at index 6503
# Non-dict data at index 6504
# Non-dict data at index 6505
# Non-dict data at index 6506
# Non-dict data at index 6507
# Non-dict data at index 6508
# Non-dict data at index 6509
# Non-dict data at index 6510
# Non-dict data at index 6511
# Non-dict data at index 6512
# Non-dict data at index 6513
# Non-dict data at index 6514
# Non-dict data at index 6515
# Non-dict data at index 6516
# Non-dict data at index 6517
# Non-dict data at index 6518
# Non-dict data at index 6519
# Non-dict data at index 6520
# Non-dict data at index 6521
# Non-dict data at index 6522
# Non-dict data at index 6523
# Non-dict data at index 6524
# Non-dict data at index 6525
# Non-dict data at index 6526
# Non-dict data at index 6527
# Non-dict data at index 6528
# Non-dict data at index 6529
# Non-dict data at index 6530
# Non-dict data at index 6531
# Non-dict data at index 6532
# Non-dict data at index 6533
# Non-dict data at index 6534
# Non-dict data at index 6535
# Non-dict data at index 6536
# Non-dict data at index 6537
# Non-dict data at index 6538
# Non-dict data at index 6539
# Non-dict data at index 6540
# Non-dict data at index 6541
# Non-dict data at index 6542
# Non-dict data at index 6543
# Non-dict data at index 6544
# Non-dict data at index 6545
# Non-dict data at index 6546
# Non-dict data at index 6547
# Non-dict data at index 6548
# Non-dict data at index 6549
# Non-dict data at index 6550
# Non-dict data at index 6551
# Non-dict data at index 6552
# Non-dict data at index 6553
# Non-dict data at index 6554
# Non-dict data at index 6555
# Non-dict data at index 6556
# Non-dict data at index 6557
# Non-dict data at index 6558
# Non-dict data at index 6559
# Non-dict data at index 6560
# Non-dict data at index 6561
# Non-dict data at index 6562
# Non-dict data at index 6563
# Non-dict data at index 6564
# Non-dict data at index 6565
# Non-dict data at index 6566
# Non-dict data at index 6567
# Non-dict data at index 6568
# Non-dict data at index 6569
# Non-dict data at index 6570
# Non-dict data at index 6571
# Non-dict data at index 6572
# Non-dict data at index 6573
# Non-dict data at index 6574
# Non-dict data at index 6575
# Non-dict data at index 6576
# Non-dict data at index 6577
# Non-dict data at index 6578
# Non-dict data at index 6579
# Non-dict data at index 6580
# Non-dict data at index 6581
# Non-dict data at index 6582
# Non-dict data at index 6583
# Non-dict data at index 6584
# Non-dict data at index 6585
# Non-dict data at index 6586
# Non-dict data at index 6587
# Non-dict data at index 6588
# Non-dict data at index 6589
# Non-dict data at index 6590
# Non-dict data at index 6591
# Non-dict data at index 6592
# Non-dict data at index 6593
# Non-dict data at index 6594
# Non-dict data at index 6595
# Non-dict data at index 6596
# Non-dict data at index 6597
# Non-dict data at index 6598
# Non-dict data at index 6599
# Non-dict data at index 6600
# Non-dict data at index 6601
# Non-dict data at index 6602
# Non-dict data at index 6603
# Non-dict data at index 6604
# Non-dict data at index 6605
# Non-dict data at index 6606
# Non-dict data at index 6607
# Non-dict data at index 6608
# Non-dict data at index 6609
# Non-dict data at index 6610
# Non-dict data at index 6611
# Non-dict data at index 6612
# Non-dict data at index 6613
# Non-dict data at index 6614
# Non-dict data at index 6615
# Non-dict data at index 6616
# Non-dict data at index 6617
# Non-dict data at index 6618
# Non-dict data at index 6619
# Non-dict data at index 6620
# Non-dict data at index 6621
# Non-dict data at index 6622
# Non-dict data at index 6623
# Non-dict data at index 6624
# Non-dict data at index 6625
# Non-dict data at index 6626
# Non-dict data at index 6627
# Non-dict data at index 6628
# Non-dict data at index 6629
# Non-dict data at index 6630
# Non-dict data at index 6631
# Non-dict data at index 6632
# Non-dict data at index 6633
# Non-dict data at index 6634
# Non-dict data at index 6635
# Non-dict data at index 6636
# Non-dict data at index 6637
# Non-dict data at index 6638
# Non-dict data at index 6639
# Non-dict data at index 6640
# Non-dict data at index 6641
# Non-dict data at index 6642
# Non-dict data at index 6643
# Non-dict data at index 6644
# Non-dict data at index 6645
# Non-dict data at index 6646
# Non-dict data at index 6647
# Non-dict data at index 6648
# Non-dict data at index 6649
# Non-dict data at index 6650
# Non-dict data at index 6651
# Non-dict data at index 6652
# Non-dict data at index 6653
# Non-dict data at index 6654
# Non-dict data at index 6655
# Non-dict data at index 6656
# Non-dict data at index 6657
# Non-dict data at index 6658
# Non-dict data at index 6659
# Non-dict data at index 6660
# Non-dict data at index 6661
# Non-dict data at index 6662
# Non-dict data at index 6663
# Non-dict data at index 6664
# Non-dict data at index 6665
# Non-dict data at index 6666
# Non-dict data at index 6667
# Non-dict data at index 6668
# Non-dict data at index 6669
# Non-dict data at index 6670
# Non-dict data at index 6671
# Non-dict data at index 6672
# Non-dict data at index 6673
# Non-dict data at index 6674
# Non-dict data at index 6675
# Non-dict data at index 6676
# Non-dict data at index 6677
# Non-dict data at index 6678
# Non-dict data at index 6679
# Non-dict data at index 6680
# Non-dict data at index 6681
# Non-dict data at index 6682
# Non-dict data at index 6683
# Non-dict data at index 6684
# Non-dict data at index 6685
# Non-dict data at index 6686
# Non-dict data at index 6687
# Non-dict data at index 6688
# Non-dict data at index 6689
# Non-dict data at index 6690
# Non-dict data at index 6691
# Non-dict data at index 6692
# Non-dict data at index 6693
# Non-dict data at index 6694
# Non-dict data at index 6695
# Non-dict data at index 6696
# Non-dict data at index 6697
# Non-dict data at index 6698
# Non-dict data at index 6699
# Non-dict data at index 6700
# Non-dict data at index 6701
# Non-dict data at index 6702
# Non-dict data at index 6703
# Non-dict data at index 6704
# Non-dict data at index 6705
# Non-dict data at index 6706
# Non-dict data at index 6707
# Non-dict data at index 6708
# Non-dict data at index 6709
# Non-dict data at index 6710
# Non-dict data at index 6711
# Non-dict data at index 6712
# Non-dict data at index 6713
# Non-dict data at index 6714
# Non-dict data at index 6715
# Non-dict data at index 6716
# Non-dict data at index 6717
# Non-dict data at index 6718
# Non-dict data at index 6719
# Non-dict data at index 6720
# Non-dict data at index 6721
# Non-dict data at index 6722
# Non-dict data at index 6723
# Non-dict data at index 6724
# Non-dict data at index 6725
# Non-dict data at index 6726
# Non-dict data at index 6727
# Non-dict data at index 6728
# Non-dict data at index 6729
# Non-dict data at index 6730
# Non-dict data at index 6731
# Non-dict data at index 6732
# Non-dict data at index 6733
# Non-dict data at index 6734
# Non-dict data at index 6735
# Non-dict data at index 6736
# Non-dict data at index 6737
# Non-dict data at index 6738
# Non-dict data at index 6739
# Non-dict data at index 6740
# Non-dict data at index 6741
# Non-dict data at index 6742
# Non-dict data at index 6743
# Non-dict data at index 6744
# Non-dict data at index 6745
# Non-dict data at index 6746
# Non-dict data at index 6747
# Non-dict data at index 6748
# Non-dict data at index 6749
# Non-dict data at index 6750
# Non-dict data at index 6751
# Non-dict data at index 6752
# Non-dict data at index 6753
# Non-dict data at index 6754
# Non-dict data at index 6755
# Non-dict data at index 6756
# Non-dict data at index 6757
# Non-dict data at index 6758
# Non-dict data at index 6759
# Non-dict data at index 6760
# Non-dict data at index 6761
# Non-dict data at index 6762
# Non-dict data at index 6763
# Non-dict data at index 6764
# Non-dict data at index 6765
# Non-dict data at index 6766
# Non-dict data at index 6767
# Non-dict data at index 6768
# Non-dict data at index 6769
# Non-dict data at index 6770
# Non-dict data at index 6771
# Non-dict data at index 6772
# Non-dict data at index 6773
# Non-dict data at index 6774
# Non-dict data at index 6775
# Non-dict data at index 6776
# Non-dict data at index 6777
# Non-dict data at index 6778
# Non-dict data at index 6779
# Non-dict data at index 6780
# Non-dict data at index 6781
# Non-dict data at index 6782
# Non-dict data at index 6783
# Non-dict data at index 6784
# Non-dict data at index 6785
# Non-dict data at index 6786
# Non-dict data at index 6787
# Non-dict data at index 6788
# Non-dict data at index 6789
# Non-dict data at index 6790
# Non-dict data at index 6791
# Non-dict data at index 6792
# Non-dict data at index 6793
# Non-dict data at index 6794
# Non-dict data at index 6795
# Non-dict data at index 6796
# Non-dict data at index 6797
# Non-dict data at index 6798
# Non-dict data at index 6799
# Non-dict data at index 6800
# Non-dict data at index 6801
# Non-dict data at index 6802
# Non-dict data at index 6803
# Non-dict data at index 6804
# Non-dict data at index 6805
# Non-dict data at index 6806
# Non-dict data at index 6807
# Non-dict data at index 6808
# Non-dict data at index 6809
# Non-dict data at index 6810
# Non-dict data at index 6811
# Non-dict data at index 6812
# Non-dict data at index 6813
# Non-dict data at index 6814
# Non-dict data at index 6815
# Non-dict data at index 6816
# Non-dict data at index 6817
# Non-dict data at index 6818
# Non-dict data at index 6819
# Non-dict data at index 6820
# Non-dict data at index 6821
# Non-dict data at index 6822
# Non-dict data at index 6823
# Non-dict data at index 6824
# Non-dict data at index 6825
# Non-dict data at index 6826
# Non-dict data at index 6827
# Non-dict data at index 6828
# Non-dict data at index 6829
# Non-dict data at index 6830
# Non-dict data at index 6831
# Non-dict data at index 6832
# Non-dict data at index 6833
# Non-dict data at index 6834
# Non-dict data at index 6835
# Non-dict data at index 6836
# Non-dict data at index 6837
# Non-dict data at index 6838
# Non-dict data at index 6839
# Non-dict data at index 6840
# Non-dict data at index 6841
# Non-dict data at index 6842
# Non-dict data at index 6843
# Non-dict data at index 6844
# Non-dict data at index 6845
# Non-dict data at index 6846
# Non-dict data at index 6847
# Non-dict data at index 6848
# Non-dict data at index 6849
# Non-dict data at index 6850
# Non-dict data at index 6851
# Non-dict data at index 6852
# Non-dict data at index 6853
# Non-dict data at index 6854
# Non-dict data at index 6855
# Non-dict data at index 6856
# Non-dict data at index 6857
# Non-dict data at index 6858
# Non-dict data at index 6859
# Non-dict data at index 6860
# Non-dict data at index 6861
# Non-dict data at index 6862
# Non-dict data at index 6863
# Non-dict data at index 6864
# Non-dict data at index 6865
# Non-dict data at index 6866
# Non-dict data at index 6867
# Non-dict data at index 6868
# Non-dict data at index 6869
# Non-dict data at index 6870
# Non-dict data at index 6871
# Non-dict data at index 6872
# Non-dict data at index 6873
# Non-dict data at index 6874
# Non-dict data at index 6875
# Non-dict data at index 6876
# Non-dict data at index 6877
# Non-dict data at index 6878
# Non-dict data at index 6879
# Non-dict data at index 6880
# Non-dict data at index 6881
# Non-dict data at index 6882
# Non-dict data at index 6883
# Non-dict data at index 6884
# Non-dict data at index 6885
# Non-dict data at index 6886
# Non-dict data at index 6887
# Non-dict data at index 6888
# Non-dict data at index 6889
# Non-dict data at index 6890
# Non-dict data at index 6891
# Non-dict data at index 6892
# Non-dict data at index 6893
# Non-dict data at index 6894
# Non-dict data at index 6895
# Non-dict data at index 6896
# Non-dict data at index 6897
# Non-dict data at index 6898
# Non-dict data at index 6899
# Non-dict data at index 6900
# Non-dict data at index 6901
# Non-dict data at index 6902
# Non-dict data at index 6903
# Non-dict data at index 6904
# Non-dict data at index 6905
# Non-dict data at index 6906
# Non-dict data at index 6907
# Non-dict data at index 6908
# Non-dict data at index 6909
# Non-dict data at index 6910
# Non-dict data at index 6911
# Non-dict data at index 6912
# Non-dict data at index 6913
# Non-dict data at index 6914
# Non-dict data at index 6915
# Non-dict data at index 6916
# Non-dict data at index 6917
# Non-dict data at index 6918
# Non-dict data at index 6919
# Non-dict data at index 6920
# Non-dict data at index 6921
# Non-dict data at index 6922
# Non-dict data at index 6923
# Non-dict data at index 6924
# Non-dict data at index 6925
# Non-dict data at index 6926
# Non-dict data at index 6927
# Non-dict data at index 6928
# Non-dict data at index 6929
# Non-dict data at index 6930
# Non-dict data at index 6931
# Non-dict data at index 6932
# Non-dict data at index 6933
# Non-dict data at index 6934
# Non-dict data at index 6935
# Non-dict data at index 6936
# Non-dict data at index 6937
# Non-dict data at index 6938
# Non-dict data at index 6939
# Non-dict data at index 6940
# Non-dict data at index 6941
# Non-dict data at index 6942
# Non-dict data at index 6943
# Non-dict data at index 6944
# Non-dict data at index 6945
# Non-dict data at index 6946
# Non-dict data at index 6947
# Non-dict data at index 6948
# Non-dict data at index 6949
# Non-dict data at index 6950
# Non-dict data at index 6951
# Non-dict data at index 6952
# Non-dict data at index 6953
# Non-dict data at index 6954
# Non-dict data at index 6955
# Non-dict data at index 6956
# Non-dict data at index 6957
# Non-dict data at index 6958
# Non-dict data at index 6959
# Non-dict data at index 6960
# Non-dict data at index 6961
# Non-dict data at index 6962
# Non-dict data at index 6963
# Non-dict data at index 6964
# Non-dict data at index 6965
# Non-dict data at index 6966
# Non-dict data at index 6967
# Non-dict data at index 6968
# Non-dict data at index 6969
# Non-dict data at index 6970
# Non-dict data at index 6971
# Non-dict data at index 6972
# Non-dict data at index 6973
# Non-dict data at index 6974
# Non-dict data at index 6975
# Non-dict data at index 6976
# Non-dict data at index 6977
# Non-dict data at index 6978
# Non-dict data at index 6979
# Non-dict data at index 6980
# Non-dict data at index 6981
# Non-dict data at index 6982
# Non-dict data at index 6983
# Non-dict data at index 6984
# Non-dict data at index 6985
# Non-dict data at index 6986
# Non-dict data at index 6987
# Non-dict data at index 6988
# Non-dict data at index 6989
# Non-dict data at index 6990
# Non-dict data at index 6991
# Non-dict data at index 6992
# Non-dict data at index 6993
# Non-dict data at index 6994
# Non-dict data at index 6995
# Non-dict data at index 6996
# Non-dict data at index 6997
# Non-dict data at index 6998
# Non-dict data at index 6999
# Non-dict data at index 7000
# Non-dict data at index 7001
# Non-dict data at index 7002
# Non-dict data at index 7003
# Non-dict data at index 7004
# Non-dict data at index 7005
# Non-dict data at index 7006
# Non-dict data at index 7007
# Non-dict data at index 7008
# Non-dict data at index 7009
# Non-dict data at index 7010
# Non-dict data at index 7011
# Non-dict data at index 7012
# Non-dict data at index 7013
# Non-dict data at index 7014
# Non-dict data at index 7015
# Non-dict data at index 7016
# Non-dict data at index 7017
# Non-dict data at index 7018
# Non-dict data at index 7019
# Non-dict data at index 7020
# Non-dict data at index 7021
# Non-dict data at index 7022
# Non-dict data at index 7023
# Non-dict data at index 7024
# Non-dict data at index 7025
# Non-dict data at index 7026
# Non-dict data at index 7027
# Non-dict data at index 7028
# Non-dict data at index 7029
# Non-dict data at index 7030
# Non-dict data at index 7031
# Non-dict data at index 7032
# Non-dict data at index 7033
# Non-dict data at index 7034
# Non-dict data at index 7035
# Non-dict data at index 7036
# Non-dict data at index 7037
# Non-dict data at index 7038
# Non-dict data at index 7039
# Non-dict data at index 7040
# Non-dict data at index 7041
# Non-dict data at index 7042
# Non-dict data at index 7043
# Non-dict data at index 7044
# Non-dict data at index 7045
# Non-dict data at index 7046
# Non-dict data at index 7047
# Non-dict data at index 7048
# Non-dict data at index 7049
# Non-dict data at index 7050
# Non-dict data at index 7051
# Non-dict data at index 7052
# Non-dict data at index 7053
# Non-dict data at index 7054
# Non-dict data at index 7055
# Non-dict data at index 7056
# Non-dict data at index 7057
# Non-dict data at index 7058
# Non-dict data at index 7059
# Non-dict data at index 7060
# Non-dict data at index 7061
# Non-dict data at index 7062
# Non-dict data at index 7063
# Non-dict data at index 7064
# Non-dict data at index 7065
# Non-dict data at index 7066
# Non-dict data at index 7067
# Non-dict data at index 7068
# Non-dict data at index 7069
# Non-dict data at index 7070
# Non-dict data at index 7071
# Non-dict data at index 7072
# Non-dict data at index 7073
# Non-dict data at index 7074
# Non-dict data at index 7075
# Non-dict data at index 7076
# Non-dict data at index 7077
# Non-dict data at index 7078
# Non-dict data at index 7079
# Non-dict data at index 7080
# Non-dict data at index 7081
# Non-dict data at index 7082
# Non-dict data at index 7083
# Non-dict data at index 7084
# Non-dict data at index 7085
# Non-dict data at index 7086
# Non-dict data at index 7087
# Non-dict data at index 7088
# Non-dict data at index 7089
# Non-dict data at index 7090
# Non-dict data at index 7091
# Non-dict data at index 7092
# Non-dict data at index 7093
# Non-dict data at index 7094
# Non-dict data at index 7095
# Non-dict data at index 7096
# Non-dict data at index 7097
# Non-dict data at index 7098
# Non-dict data at index 7099
# Non-dict data at index 7100
# Non-dict data at index 7101
# Non-dict data at index 7102
# Non-dict data at index 7103
# Non-dict data at index 7104
# Non-dict data at index 7105
# Non-dict data at index 7106
# Non-dict data at index 7107
# Non-dict data at index 7108
# Non-dict data at index 7109
# Non-dict data at index 7110
# Non-dict data at index 7111
# Non-dict data at index 7112
# Non-dict data at index 7113
# Non-dict data at index 7114
# Non-dict data at index 7115
# Non-dict data at index 7116
# Non-dict data at index 7117
# Non-dict data at index 7118
# Non-dict data at index 7119
# Non-dict data at index 7120
# Non-dict data at index 7121
# Non-dict data at index 7122
# Non-dict data at index 7123
# Non-dict data at index 7124
# Non-dict data at index 7125
# Non-dict data at index 7126
# Non-dict data at index 7127
# Non-dict data at index 7128
# Non-dict data at index 7129
# Non-dict data at index 7130
# Non-dict data at index 7131
# Non-dict data at index 7132
# Non-dict data at index 7133
# Non-dict data at index 7134
# Non-dict data at index 7135
# Non-dict data at index 7136
# Non-dict data at index 7137
# Non-dict data at index 7138
# Non-dict data at index 7139
# Non-dict data at index 7140
# Non-dict data at index 7141
# Non-dict data at index 7142
# Non-dict data at index 7143
# Non-dict data at index 7144
# Non-dict data at index 7145
# Non-dict data at index 7146
# Non-dict data at index 7147
# Non-dict data at index 7148
# Non-dict data at index 7149
# Non-dict data at index 7150
# Non-dict data at index 7151
# Non-dict data at index 7152
# Non-dict data at index 7153
# Non-dict data at index 7154
# Non-dict data at index 7155
# Non-dict data at index 7156
# Non-dict data at index 7157
# Non-dict data at index 7158
# Non-dict data at index 7159
# Non-dict data at index 7160
# Non-dict data at index 7161
# Non-dict data at index 7162
# Non-dict data at index 7163
# Non-dict data at index 7164
# Non-dict data at index 7165
# Non-dict data at index 7166
# Non-dict data at index 7167
# Non-dict data at index 7168
# Non-dict data at index 7169
# Non-dict data at index 7170
# Non-dict data at index 7171
# Non-dict data at index 7172
# Non-dict data at index 7173
# Non-dict data at index 7174
# Non-dict data at index 7175
# Non-dict data at index 7176
# Non-dict data at index 7177
# Non-dict data at index 7178
# Non-dict data at index 7179
# Non-dict data at index 7180
# Non-dict data at index 7181
# Non-dict data at index 7182
# Non-dict data at index 7183
# Non-dict data at index 7184
# Non-dict data at index 7185
# Non-dict data at index 7186
# Non-dict data at index 7187
# Non-dict data at index 7188
# Non-dict data at index 7189
# Non-dict data at index 7190
# Non-dict data at index 7191
# Non-dict data at index 7192
# Non-dict data at index 7193
# Non-dict data at index 7194
# Non-dict data at index 7195
# Non-dict data at index 7196
# Non-dict data at index 7197
# Non-dict data at index 7198
# Non-dict data at index 7199
# Non-dict data at index 7200
# Non-dict data at index 7201
# Non-dict data at index 7202
# Non-dict data at index 7203
# Non-dict data at index 7204
# Non-dict data at index 7205
# Non-dict data at index 7206
# Non-dict data at index 7207
# Non-dict data at index 7208
# Non-dict data at index 7209
# Non-dict data at index 7210
# Non-dict data at index 7211
# Non-dict data at index 7212
# Non-dict data at index 7213
# Non-dict data at index 7214
# Non-dict data at index 7215
# Non-dict data at index 7216
# Non-dict data at index 7217
# Non-dict data at index 7218
# Non-dict data at index 7219
# Non-dict data at index 7220
# Non-dict data at index 7221
# Non-dict data at index 7222
# Non-dict data at index 7223
# Non-dict data at index 7224
# Non-dict data at index 7225
# Non-dict data at index 7226
# Non-dict data at index 7227
# Non-dict data at index 7228
# Non-dict data at index 7229
# Non-dict data at index 7230
# Non-dict data at index 7231
# Non-dict data at index 7232
# Non-dict data at index 7233
# Non-dict data at index 7234
# Non-dict data at index 7235
# Non-dict data at index 7236
# Non-dict data at index 7237
# Non-dict data at index 7238
# Non-dict data at index 7239
# Non-dict data at index 7240
# Non-dict data at index 7241
# Non-dict data at index 7242
# Non-dict data at index 7243
# Non-dict data at index 7244
# Non-dict data at index 7245
# Non-dict data at index 7246
# Non-dict data at index 7247
# Non-dict data at index 7248
# Non-dict data at index 7249
# Non-dict data at index 7250
# Non-dict data at index 7251
# Non-dict data at index 7252
# Non-dict data at index 7253
# Non-dict data at index 7254
# Non-dict data at index 7255
# Non-dict data at index 7256
# Non-dict data at index 7257
# Non-dict data at index 7258
# Non-dict data at index 7259
# Non-dict data at index 7260
# Non-dict data at index 7261
# Non-dict data at index 7262
# Non-dict data at index 7263
# Non-dict data at index 7264
# Non-dict data at index 7265
# Non-dict data at index 7266
# Non-dict data at index 7267
# Non-dict data at index 7268
# Non-dict data at index 7269
# Non-dict data at index 7270
# Non-dict data at index 7271
# Non-dict data at index 7272
# Non-dict data at index 7273
# Non-dict data at index 7274
# Non-dict data at index 7275
# Non-dict data at index 7276
# Non-dict data at index 7277
# Non-dict data at index 7278
# Non-dict data at index 7279
# Non-dict data at index 7280
# Non-dict data at index 7281
# Non-dict data at index 7282
# Non-dict data at index 7283
# Non-dict data at index 7284
# Non-dict data at index 7285
# Non-dict data at index 7286
# Non-dict data at index 7287
# Non-dict data at index 7288
# Non-dict data at index 7289
# Non-dict data at index 7290
# Non-dict data at index 7291
# Non-dict data at index 7292
# Non-dict data at index 7293
# Non-dict data at index 7294
# Non-dict data at index 7295
# Non-dict data at index 7296
# Non-dict data at index 7297
# Non-dict data at index 7298
# Non-dict data at index 7299
# Non-dict data at index 7300
# Non-dict data at index 7301
# Non-dict data at index 7302
# Non-dict data at index 7303
# Non-dict data at index 7304
# Non-dict data at index 7305
# Non-dict data at index 7306
# Non-dict data at index 7307
# Non-dict data at index 7308
# Non-dict data at index 7309
# Non-dict data at index 7310
# Non-dict data at index 7311
# Non-dict data at index 7312
# Non-dict data at index 7313

# %% [markdown]
# # Section: Processing Sellers and Product Information

# %%
# Step 1: Extract relevant columns and define the converter function for 'sellers'
df_new = df[['sellers', 'ASIN']]

def converter(record: str):
    try:
        # Remove brackets and split the string into individual elements
        list_of_dictionaries = record.strip('][').split(', ')
        # Handle boolean values represented as strings
        converted_list = list_of_dictionaries[0].replace("true", "'true'").replace("false", "'false'")
        check_point = ast.literal_eval(converted_list)
        # Check if the result is a dictionary, if so, return it as a list
        if isinstance(check_point, dict):
            final_list = [check_point]
        else:
            # Otherwise, convert it into a list
            final_list = list(check_point)
        return final_list
    except:
        return []

# Apply the converter function to the 'sellers' column
df_new['sellers'] = df_new['sellers'].map(lambda x: converter(x), na_action='ignore')

# Step 2: Processing and expanding 'sellers' data
total = pd.DataFrame()
dataframeS = []

for i in range(len(df_new)):
    asin_list = []
    asin_list.extend(repeat(df_new.ASIN.loc[i], len(df_new.sellers.loc[i])))  # Repeat ASINs for each seller
    target = pd.DataFrame(df_new.sellers.loc[i], index=asin_list).iloc[::-1]  # Reverse the order
    dataframeS.append(target)

# Concatenate the processed DataFrames into one
total = pd.concat(dataframeS)
total.index.name = 'ASIN'
total = total.rename(columns={"name": "seller_name"})
total = total.reset_index()

# Step 3: Merging with main DataFrame and product information
df = pd.merge(df, total, on='ASIN', how='left')
df = pd.merge(df, pi_combined, on='ASIN', how='left')

# Step 4: Selecting and renaming columns
df = df.rename(columns={'price': 'seller_price'})
df.drop_duplicates(inplace=True)

# Step 5: Exporting to Excel
filename = f"amazon_retail_data_{current_date}.xlsx"
downloads_folder = os.path.join(os.path.expanduser("~"), "Downloads")
file_path = os.path.join(downloads_folder, filename)
# Save the DataFrame to Excel with the new filename
df.to_excel(file_path)
# Out:
# C:\Users\Aykut\AppData\Local\Temp\ipykernel_3884\2705296750.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_new['sellers'] = df_new['sellers'].map(lambda x: converter(x), na_action='ignore')

# %% [markdown]
# # Excel Formatting and Styling

# %%
# Load the workbook and select the active worksheet
wb = load_workbook(filename=file_path)
ws = wb.active

# Apply auto filter to the worksheet
ws.auto_filter.ref = ws.dimensions

# Define common styles
font = Font(size=15, bold=True)
wrap_alignment = Alignment(wrapText=True)
left_alignment = Alignment(horizontal='left')
fill = PatternFill("solid", fgColor="00CCFFCC")
thin_border = Border(
    top=Side(border_style='thin', color="FF000000"),
    bottom=Side(border_style='thin', color="FF000000"),
    left=Side(border_style='thin', color="FF000000"),
    right=Side(border_style='thin', color="FF000000")
)

# Set row heights and apply left alignment to all rows
last_row = ws.max_row
for i in range(2, last_row + 1):
    ws.row_dimensions[i].height = 15

# Apply number format to specific columns
for col in ["B", "AJ"]:
    for cell in ws[col]:
        cell.number_format = numbers.FORMAT_NUMBER

# Apply alignment, border, and wrapping to all cells
for row in ws.iter_rows(min_row=1, max_row=last_row):
    for cell in row:
        cell.alignment = left_alignment  # Left alignment for all cells
        cell.border = thin_border        # Thin border for all cells
        cell.alignment = wrap_alignment  # Enable text wrapping for all cells

# Apply font and fill to header (first row)
for cell in ws["1:1"]:
    cell.font = font
    cell.fill = fill

# Freeze the top row and first column
ws.freeze_panes = ws["B2"]

# Set a standard column width for all columns
for col in ws.columns:
    ws.column_dimensions[col[0].column_letter].width = 30

# Save the formatted workbook
styled_file_path = os.path.join(downloads_folder, f"amazon_retail_data_{current_date}_styled.xlsx")
wb.save(styled_file_path)

print(f"Styled Excel file saved to: {styled_file_path}")
# Out:
# Styled Excel file saved to: C:\Users\Aykut\Downloads\amazon_retail_data_20241013_styled.xlsx
